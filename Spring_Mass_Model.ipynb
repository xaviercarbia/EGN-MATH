# %% [markdown]
# <a href="https://colab.research.google.com/github/xaviercarbia/EGN-MATH/blob/main/Spring_Mass_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Spring-Mass Model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $Taylor's Theorem ofCalculus$

# %% [markdown]
# $F(x)=F(0) + F^\prime(0) + \frac{1}{2} F^{\prime \prime} (0)x^2
# +... = -kx + \frac{1}{2} F^ {\prime \prime} (0)x^2 +...$

# %% [markdown]
# $Hooke's Law$

# %% [markdown]
# $F=-kx$

# %% [markdown]
# $Newton's Second Law Of Motion$

# %% [markdown]
# $F=ma=m \frac{d^2x}{dt^2}=mx^{\prime \prime}$

# %% [markdown]
# $Second Order Differential Equation$

# %% [markdown]
# $mx^{\prime \prime}=-kx$

# %% [markdown]
# $F=-bx^{\prime}$

# %% [markdown]
# $mx^{\prime \prime}=-bx^{\prime}-kx$

# %% [markdown]
# Simple Damped Harmonic Oscillator

# %% [markdown]
# $mx^{\prime \prime}+bx^{\prime}+kx=0$

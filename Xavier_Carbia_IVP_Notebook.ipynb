# %% [markdown]
# <a href="https://colab.research.google.com/github/xaviercarbia/EGN-MATH/blob/main/Xavier_Carbia_IVP_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def dx_dt(x):
  return 0.2*x

# %%
position = 400 
time0 = 0 #Starting Time
timef = 60 #Final Stopping Time
dt = 0.004 # Time Step Size
n = int((tf-t0)/dt)
n
# Out:
# 15000

# %%
import numpy as np

# %%
X = np.zeros(n,)

# %%
for i in range(n):

    x = x + dx_dt(x, t)*dt

    X[i] = x

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,20))
plt.plot(X,'.');

# %%
def dx_dt(x,t):
    return -0.2*x

# %%
import numpy as np

# %%
position = 300
time = 0
dt = 0.003
n = 300000
X = np.zeros(n,)

# %%
for i in range(n):

    x = x + dx_dt(x,t)*dt

    X[i] = x

# %%
plt.figure(figsize=(20,20))
plt.plot(X);

# %%
model = np.array([[0,1],[-2,-0.1]])

# %%
def matprint(mat, fmt="g"):
    col_maxes = [max([len(("{:"+fmt+"}").format(x)) for x in col]) for col in mat.T]
    for x in mat:
        for i, y in enumerate(x):
            print(("{:"+str(col_maxes[i])+fmt+"}").format(y), end="  ")
        print("")

# %%
matprint(model)
# Out:
#  0     2
# -3  -0.2

# %%
plt.matshow(model)

# %%
def dx_dt(x,t):
    return model @ x

# %%
d = 2
x = np.array([0,1])

t  = 0
tf = 50
dt = 0.001

n = int((tf-t)/dt)

X = np.zeros((n,d))

# %%
for i in range(n):

    x = x + dx_dt(x,t)*dt

    X[i] = x

# %%
plt.plot(X[:,0]);

# %%
def dx_dt(x,t):
    return np.array([
                      alpha*x[0]  - beta*x[0]*x[1],
                                   delta*x[0]*x[1] - gamma*x[1]  
    ])

# %%
d = 2
x = np.zeros(d,)

x[0] = 10
x[1] = 10

t  = 0
tf = 50
dt = 0.001

n = int((tf-t)/dt)
X = np.zeros((n,d))

# %%
alpha = 1 
beta = 0.05 
delta = 0.02
gamma = 0.5

# %%
for i in range(n):

    x = x + dx_dt(x,t)*dt

    X[i] = x

# %%
plt.plot(X)

# %% [markdown]
# Double-click (or enter) to edit
#
# 𝑑𝑥𝑑𝑡=𝜎(𝑦−𝑥)
#
# 𝑑𝑦𝑑𝑡=𝑥(𝑝−𝑧)−𝑦
#
# 𝑑𝑧𝑑𝑡=𝑥𝑦−𝛽𝑧

# %%
rho = 27.0
sigma = 10.0
beta = 7.0 / 2.0

# %%
model = np.array([[-sigma,sigma,0,0,0],[rho,-1,0,0,-1],[0,0,-beta,1,0]])

# %%
matprint(model)
# Out:
# -10  10     0  0   0
#  27  -1     0  0  -1
#   0   0  -3.5  1   0

# %%
plt.matshow(model)

# %%
def dx_dt(x, t):
    x, y, z = x
    state = np.array([x,y,z,x*y,x*z])
    return model @ state

# %%
d = 3
x = np.array([1,1,1])

t  = 0
tf = 50
dt = 0.001

n = int((tf-t)/dt)
X = np.zeros((n,d))

# %%
for i in range(n):

    x = x + dx_dt(x,t)*dt

    X[i] = x

# %%
fig = plt.figure()
ax = fig.gca(projection="3d")
ax.plot(X[:, 0], X[:, 1], X[:, 2]);
